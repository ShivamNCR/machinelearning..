# %% [markdown]
# # Isolation Forest Anomaly Detection

# %%
import pandas as pd
df=pd.read_csv('winequality-red.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
import matplotlib.pyplot as plt
plt.scatter(df.iloc[:,0],df.iloc[:,10])

# %%
from sklearn.ensemble import IsolationForest

# %%
clf=IsolationForest(contamination=0.02)
clf.fit(df)
predictions=clf.predict(df)

# %%
predictions
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
import numpy as np
index=np.where(predictions<0)
index
# Out:
# (array([  94,  151,  258,  353,  354,  396,  400,  442,  480,  515,  554,
#          555,  557,  588,  652,  723, 1017, 1018, 1079, 1081, 1114, 1235,
#         1244, 1269, 1319, 1434, 1435, 1474, 1476, 1558, 1574], dtype=int64),)

# %%
x=df.values

# %%
index=np.where(predictions<0)
plt.scatter(df.iloc[:,0],df.iloc[:,10])
plt.scatter(x[index,0],x[index,10],edgecolor="r")
